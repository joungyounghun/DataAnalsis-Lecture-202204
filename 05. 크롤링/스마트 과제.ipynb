# %% [markdown]
# - 1. (크롤링) 셀레니움으로 크롤링을 해서 소방서명, 주소, 전화번호
#    데이터를 가져와서 데이터프레임을 만든 후,
#    데이터프레임에 새로운 컬럼 안전센터여부를 만들고 소방서는 0,
#    안전센터는 1로 채우세요. (40점)

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from bs4 import BeautifulSoup

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://www.nfa.go.kr/nfa/introduce/status/firestationidfo/'
driver = webdriver.Chrome()
driver.get(url)

# %%
driver.find_element_by_id('searchKeyword').send_keys('서울')
driver.find_element_by_id('fsSearchBtn').click()

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
lis = soup.select('.stations-list > li')
len(lis)
# Out:
# 10

# %%
li = lis[1]
name = li.select_one('.title').get_text().strip()
name
# Out:
# '서대문소방서'

# %%
addr = li.find('address').get_text().strip()
addr
# Out:
# '서울특별시 서대문구 연희로 182(연희동)'

# %%
tel = li.select_one('.tel').get_text().strip()
tel
# Out:
# '02-3144-1190'

# %%
lines = []
for li in lis:
    name = li.select_one('.title').get_text().strip()
    addr = li.find('address').get_text().strip()
    tel = li.select_one('.tel').get_text().strip()
    lines.append([name, addr, tel])

# %%
lines

# %%
driver.find_element_by_xpath('//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').click()

# %%
lines = []
for i in range(10):
    if i >= 1 and i%2 == 0:
        driver.find_element_by_css_selector('.next_page').click()
        time.sleep(2)
    if i >= 1 and i%2 == 1:
        driver.find_element_by_xpath('//*[@id="listForm"]/div/section/ul/li[1]/div/div/ul/li[4]/a').click()
        time.sleep(2)

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    lis = soup.select('.stations-list > li')
    for li in lis:
        name = li.select_one('.title').get_text().strip()
        addr = li.find('address').get_text().strip()
        tel = li.select_one('.tel').get_text().strip()
        lines.append([name, addr, tel])

# %%
len(lines)
# Out:
# 100

# %%
driver.close()

# %%
df = pd.DataFrame(lines, columns=['소방서명','주소','전화번호'])
df.tail()
# Out:
#                   소방서명                         주소          전화번호
# 95  송파소방서-운동장-119 안전센터    서울특별시 송파구 올림픽로 25 (잠실동)  02-2203-2380
# 96   송파소방서-잠실-119 안전센터  서울특별시 송파구 석촌호수로 151 (잠실동)   02-422-0119
# 97   송파소방서-방이-119 안전센터   서울특별시 송파구 강동대로 286 (방이동)   02-409-0059
# 98   송파소방서-거여-119 안전센터    서울특별시 송파구 마천로 329 (마천동)   02-400-0119
# 99   송파소방서-마천-119 안전센터  서울특별시 송파구 오금로51길 56 (마천동)  02-3401-2119

# %%
df['안전센터'] = df.소방서명.str.contains('안전센터').astype(int)
df.head(50)
# Out:
#                       소방서명                           주소          전화번호  안전센터
# 0                    마포소방서        서울특별시 마포구 창전로 76(신수동)   02-716-0604     0
# 1                    강서소방서       서울특별시 강서구 양천로 550(등촌동)  02-3663-0119     0
# 2                    구로소방서       서울특별시 구로구 경인로 408(고척동)  02-2618-0119     0
# 3                    성동소방서      서울특별시 성동구 살곶이길 331(행당동)  02-2622-1777     0
# 4                    관악소방서        서울특별시 관악구 관악로 97(봉천동)   02-874-8119     0
# 5                    서초소방서       서울특별시 서초구 사평대로 67(반포동)   02-537-0119     0
# 6                    중부소방서        서울특별시 중구 퇴계로 394(무학동)  02-2234-0119     0
# 7                    강동소방서        서울특별시 강동구 성내로 39(성내동)   02-470-0119     0
# 8                    강북소방서            서울특별시 강북구 한천로 911  02-6946-0119     0
# 9                    성북소방서     서울특별시 성북구 종암로 27길 3(종암동)   02-921-0119     0
# 10                   마포소방서        서울특별시 마포구 창전로 76(신수동)   02-716-0604     0
# ...

# %% [markdown]
# - 2. (OpenAPI) 앞에서 구한 주소를 가지고, 카카오 로컬 Open API를
#    이용하여 소방서의 위도, 경도 정보를 구한 후 데이터프레임에
#    추가하세요. (30점)

# %%
import requests
from urllib.parse import quote

# %%
with open('kakaoapikey.txt') as file:
    kakao_key = file.read()

# %%
local_url = 'https://dapi.kakao.com/v2/local/search/address.json'
header = {'Authorization': f'KakaoAK {kakao_key}'}

# %%
df.주소[30]='서울특별시 은평구 통일로 962(진관동)'

# %%
lng_list, lat_list = [], []
for i in df.index:
    url = f'{local_url}?query={quote(df.주소[i])}'
    result = requests.get(url, headers=header).json()
    try:
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except:
        print(df.소방서명[i])

# %%
df[df.소방서명.isin(["은평소방서"])].주소
# Out:
# Series([], Name: 주소, dtype: object)

# %%
url = f'{local_url}?query={quote("서울특별시 은평구 통일로 962(진관동)")}'
result = requests.get(url, headers=header).json()
result['documents'][0]['x']
# Out:
# '126.919886803981'

# %%
lng_list, lat_list = [], []
for i in df.index:
    url = f'{local_url}?query={quote(df.주소[i])}'
    result = requests.get(url, headers=header).json()
    try:
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except:
        print(df.소방서명[i])

# %%
df['위도'] = lat_list
df['경도'] = lng_list
df.head(3)
# Out:
#     소방서명                      주소          전화번호  안전센터         위도          경도
# 0  마포소방서   서울특별시 마포구 창전로 76(신수동)   02-716-0604     0  37.549373  126.933178
# 1  강서소방서  서울특별시 강서구 양천로 550(등촌동)  02-3663-0119     0  37.558246  126.860047
# 2  구로소방서  서울특별시 구로구 경인로 408(고척동)  02-2618-0119     0  37.497793  126.865216

# %%
import folium

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],
        
        tooltip=f'{df.소방서명[i]}'f'{df.전화번호[i]}',
        
        popup=folium.Popup(df.주소[i], max_width=200),
        
        icon=folium.Icon(icon='glyphicon glyphicon-star' if df.안전센터[i]== 1  else 'glyphicon glyphicon-thumbs-up')
    ).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">서울소재 소방서 위치</h3>'    
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
